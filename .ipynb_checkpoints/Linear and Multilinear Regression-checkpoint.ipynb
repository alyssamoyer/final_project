# %%
#Import Dependencies
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
#import Files
file ='resources/all_data_final.csv'
alldata = pd.read_csv(file)

# %%
linear1={}
multilinear2={}
multilinear3={}
multilinear4={}

# %% [markdown]
# # Regression on All Factors

# %%
#Perform Linear Regression on every variable
results ={}
for value in alldata.columns[4:]:
    #Choose columns
    fewdata = alldata[["Country","Year","Life Expectancy",value]].copy()
    X = fewdata[value].values.reshape(-1, 1)
    y = fewdata["Life Expectancy"].values.reshape(-1, 1)
    
    #Split Data into Train and Test
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    model = LinearRegression()

    model.fit(X_train, y_train)
    training_score = model.score(X_train, y_train)
    testing_score = model.score(X_test, y_test)
    
    results[value] = {"Training Score":training_score,"Testing Score": testing_score, "Coefficent": model.coef_[0][0], "y intercept": model.intercept_[0]} 
scores = pd.DataFrame(results)
linearall = scores.transpose().sort_values(by=['Training Score'], ascending=False)
linear1["linearall"]=linearall
linearall.head()
# Out:
#                  Training Score  Testing Score  Coefficent  y intercept
# Water                  0.644399       0.595419    0.396541    36.553143
# Birth Per Woman        0.619169       0.632008   -4.971788    84.124396
# Schooling              0.552045       0.531801    2.432881    39.726010
# Adult Mortality        0.511357       0.601121   -0.051683    78.248466
# Hiv/Aids               0.367505       0.411701   -1.032637    71.909438

# %%
#Graphing Single Regression Results
lab = linearall.index
y = np.arange(len(lab))
width = 0.35
fig, ax = plt.subplots(figsize=(10, 10))
rects1 = ax.barh(y - width/2, linearall["Training Score"],width, label="Training Score")
rects2 = ax.barh(y + width/2, linearall["Testing Score"],width, label="Testing Score")
ax.set_ylabel('Variables')
ax.set_title('Linear Regression')
ax.set_yticks(y)
ax.set_yticklabels(lab)
ax.legend()
plt.tight_layout()
plt.savefig('images/linearall.png')

# %%
#multilinear regression with 2 variables
others =alldata.columns[4:]
resultstoo = {}
for o1 in range(len(others)-1):
    value=others[o1]
    otherstoo = others[1:]
    for other in otherstoo:
        fewdata = alldata[["Country","Year","Life Expectancy",value, other]].copy()
        if value != other:
            theX = [value, other]
            theX.sort()
            X = fewdata[theX]
            y = fewdata["Life Expectancy"].values.reshape(-1, 1)
            #Split Data into Train and Test
            X_train, X_test, y_train, y_test = train_test_split(X, y)

            model = LinearRegression()

            model.fit(X_train, y_train)
            training_score = model.score(X_train, y_train)
            testing_score = model.score(X_test, y_test)

            resultstoo[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1], "y intercept": model.intercept_[0]} 
scorestoo = pd.DataFrame(resultstoo)
scorestoo=scorestoo.transpose().sort_values(by=['Training Score'], ascending=False)
multilinear2["all"]=scorestoo
multilinear2["all"].head()
# Out:
#                                   Training Score Testing Score  \
# Adult Mortality & Water                 0.770127      0.753388
# Hiv/Aids & Water                         0.76625      0.737985
# Adult Mortality & Birth Per Woman       0.765158      0.778782
# Birth Per Woman & Hiv/Aids              0.760832      0.766312
# Hiv/Aids & Schooling                     0.75847      0.734978
#
#                                           Variable Coefficent  \
# Adult Mortality & Water            Adult Mortality -0.0306502
# Hiv/Aids & Water                             Water  -0.653128
# Adult Mortality & Birth Per Woman  Adult Mortality -0.0310667
# Birth Per Woman & Hiv/Aids         Birth Per Woman   -4.12153
# Hiv/Aids & Schooling                     Schooling  -0.781815
#
#                                     Other Variable Coefficent2 y intercept
# Adult Mortality & Water                      Water    0.284543     50.9861
# Hiv/Aids & Water                          Hiv/Aids    0.333625     43.0601
# Adult Mortality & Birth Per Woman  Birth Per Woman    -3.39954     84.6635
# Birth Per Woman & Hiv/Aids                Hiv/Aids    -0.67976     82.8611
# Hiv/Aids & Schooling                      Hiv/Aids     2.01342     46.4514

# %%
#Graphing 2Variable Regression Results

top5 = multilinear2["all"][:5]
lab = top5.index
y = np.arange(len(lab))
width = 0.35
fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
ax.set_ylabel('Variables')
ax.set_title(f' Multilinear Regression with 2 Variables')
ax.set_yticks(y)
ax.set_yticklabels(lab)
ax.legend()
plt.tight_layout()
plt.savefig(f'images/all2.png')

# %%
#multilinear regression with 3 variables
others = alldata.columns[4:]
resultsthree ={}
for o1 in range(len(others)-2):
        value=others[o1]
        otherstoo = others[1:]
        for o2 in range(len(otherstoo)-1):
            other=otherstoo[o2+1]
            othersthree = otherstoo[1:]
            for other2 in othersthree:
                fewdata = alldata[["Country","Year","Life Expectancy",value, other, other2]].copy()
                if (value != other) and (value != other2) and (other2 != other):
                    theX = [value, other, other2]
                    theX.sort()
                    X = fewdata[theX]
                    y = fewdata["Life Expectancy"].values.reshape(-1, 1)
                    #Split Data into Train and Test
                    X_train, X_test, y_train, y_test = train_test_split(X, y)

                    model = LinearRegression()
                    model.fit(X_train, y_train)
                    training_score = model.score(X_train, y_train)
                    testing_score = model.score(X_test, y_test)
                
                    resultsthree[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1],"Other Variable2":other2,f"Coefficent3": model.coef_[0][2], "y intercept": model.intercept_[0]} 
scoresthree = pd.DataFrame(resultsthree)
scoresthree= scoresthree.transpose().sort_values(by=['Training Score'], ascending=False)
multilinear3["all"]=scoresthree
multilinear3["all"].head()
# Out:
#                                                    Training Score  \
# Hiv/Aids & Schooling & Water                             0.814263
# Adult Mortality & Birth Per Woman & Hiv/Aids             0.812491
# Birth Per Woman & Hiv/Aids & Schooling                   0.812192
# Adult Mortality & Thinness 5-9 Years & Water             0.810798
# Birth Per Woman & Hiv/Aids & Percentage Expendi...       0.808199
#
#                                                    Testing Score  \
# Hiv/Aids & Schooling & Water                            0.816595
# Adult Mortality & Birth Per Woman & Hiv/Aids            0.767397
# Birth Per Woman & Hiv/Aids & Schooling                  0.823948
# Adult Mortality & Thinness 5-9 Years & Water            0.748227
# Birth Per Woman & Hiv/Aids & Percentage Expendi...      0.764812
#
#                                                            Variable  \
# Hiv/Aids & Schooling & Water                                  Water
# Adult Mortality & Birth Per Woman & Hiv/Aids        Adult Mortality
# Birth Per Woman & Hiv/Aids & Schooling              Birth Per Woman
# Adult Mortality & Thinness 5-9 Years & Water        Adult Mortality
# Birth Per Woman & Hiv/Aids & Percentage Expendi...  Birth Per Woman
#
#                                                    Coefficent  \
# Hiv/Aids & Schooling & Water                        -0.678089
# Adult Mortality & Birth Per Woman & Hiv/Aids       -0.0204399
# Birth Per Woman & Hiv/Aids & Schooling               -2.48092
# Adult Mortality & Thinness 5-9 Years & Water       -0.0295051
# Birth Per Woman & Hiv/Aids & Percentage Expendi...   -3.57855
#
#                                                      Other Variable  \
# Hiv/Aids & Schooling & Water                              Schooling
# Adult Mortality & Birth Per Woman & Hiv/Aids        Birth Per Woman
# Birth Per Woman & Hiv/Aids & Schooling                    Schooling
# Adult Mortality & Thinness 5-9 Years & Water                  Water
# Birth Per Woman & Hiv/Aids & Percentage Expendi...         Hiv/Aids
#
#                                                    Coefficent2  \
# Hiv/Aids & Schooling & Water                           1.12664
# Adult Mortality & Birth Per Woman & Hiv/Aids          -3.46473
# Birth Per Woman & Hiv/Aids & Schooling               -0.675019
# Adult Mortality & Thinness 5-9 Years & Water         -0.332937
# Birth Per Woman & Hiv/Aids & Percentage Expendi...   -0.678595
#
#                                                            Other Variable2  \
# Hiv/Aids & Schooling & Water                                      Hiv/Aids
# Adult Mortality & Birth Per Woman & Hiv/Aids                      Hiv/Aids
# Birth Per Woman & Hiv/Aids & Schooling                            Hiv/Aids
# Adult Mortality & Thinness 5-9 Years & Water            Thinness 5-9 Years
# Birth Per Woman & Hiv/Aids & Percentage Expendi...  Percentage Expenditure
#
#                                                     Coefficent3 y intercept
# Hiv/Aids & Schooling & Water                           0.190741     41.1279
# Adult Mortality & Birth Per Woman & Hiv/Aids          -0.425102     83.7944
# Birth Per Woman & Hiv/Aids & Schooling                  1.06978      64.945
# Adult Mortality & Thinness 5-9 Years & Water           0.258185       54.51
# Birth Per Woman & Hiv/Aids & Percentage Expendi...  0.000942145     80.6293

# %%
#Graphing 3Variable Regression Results

top5 = multilinear3["all"][:5]
lab = top5.index
y = np.arange(len(lab))
width = 0.35
fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
ax.set_ylabel('Variables')
ax.set_title(f' Multilinear Regression with 3 Variables')
ax.set_yticks(y)
ax.set_yticklabels(lab)
ax.legend()
plt.tight_layout()
plt.savefig(f'images/all3.png')

# %%
#multilinear regression with 4 variables
others = alldata.columns[4:]
resultsfour ={}
for o1 in range(len(others)-3):
    value=others[o1]
    otherstoo = others[1:]
    for o2 in range(len(otherstoo)-2):
        other=otherstoo[o2+1]
        othersthree = otherstoo[1:]
        for o3 in range(len(othersthree)-1):
            other2=otherstoo[o3+2]
            othersfour = othersthree[1:]
            for other3 in othersfour:
                fewdata = alldata[["Country","Year","Life Expectancy",value, other, other2,other3]].copy()
                if (value != other) and (value != other2) and (other2 != other) and (value != other3) and (other3 != other2) and (other3 != other):
                    theX = [value, other, other2,other3]
                    theX.sort()
                    X = fewdata[theX]
                    y = fewdata["Life Expectancy"].values.reshape(-1, 1)

                    #Split Data into Train and Test
                    X_train, X_test, y_train, y_test = train_test_split(X, y)

                    model = LinearRegression()

                    model.fit(X_train, y_train)
                    training_score = model.score(X_train, y_train)
                    testing_score = model.score(X_test, y_test)

                    resultsfour[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score, "Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1],"Other Variable2":other2,f"Coefficent3": model.coef_[0][2],"Other Variable3":other3,f"Coefficent4": model.coef_[0][3], "y intercept": model.intercept_[0]} 
scoresfour = pd.DataFrame(resultsfour)
scoresfour = scoresfour.transpose().sort_values(by=['Training Score'], ascending=False)
multilinear4["all"]=scoresfour
multilinear4["all"].head()
# Out:
#                                                    Training Score  \
# Adult Mortality & Hiv/Aids & Schooling & Water           0.844869
# Birth Per Woman & Hiv/Aids & Schooling & Total ...       0.843372
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...       0.842223
# Birth Per Woman & Gdp & Hiv/Aids & Schooling             0.829296
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...        0.82846
#
#                                                    Testing Score  \
# Adult Mortality & Hiv/Aids & Schooling & Water          0.835589
# Birth Per Woman & Hiv/Aids & Schooling & Total ...      0.743969
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...      0.851131
# Birth Per Woman & Gdp & Hiv/Aids & Schooling            0.829729
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...      0.817279
#
#                                                            Variable  \
# Adult Mortality & Hiv/Aids & Schooling & Water      Adult Mortality
# Birth Per Woman & Hiv/Aids & Schooling & Total ...  Birth Per Woman
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...  Adult Mortality
# Birth Per Woman & Gdp & Hiv/Aids & Schooling        Birth Per Woman
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...  Adult Mortality
#
#                                                    Coefficent  \
# Adult Mortality & Hiv/Aids & Schooling & Water     -0.0164849
# Birth Per Woman & Hiv/Aids & Schooling & Total ...    -2.5214
# Adult Mortality & Birth Per Woman & Hiv/Aids & ... -0.0177803
# Birth Per Woman & Gdp & Hiv/Aids & Schooling         -2.49889
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year... -0.0185571
#
#                                                      Other Variable  \
# Adult Mortality & Hiv/Aids & Schooling & Water                Water
# Birth Per Woman & Hiv/Aids & Schooling & Total ...        Schooling
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...  Birth Per Woman
# Birth Per Woman & Gdp & Hiv/Aids & Schooling              Schooling
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...            Water
#
#                                                     Coefficent2  \
# Adult Mortality & Hiv/Aids & Schooling & Water         -0.47972
# Birth Per Woman & Hiv/Aids & Schooling & Total ...    -0.692733
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...     -2.07927
# Birth Per Woman & Gdp & Hiv/Aids & Schooling        9.64204e-05
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...    -0.416559
#
#                                                         Other Variable2  \
# Adult Mortality & Hiv/Aids & Schooling & Water                Schooling
# Birth Per Woman & Hiv/Aids & Schooling & Total ...             Hiv/Aids
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...            Schooling
# Birth Per Woman & Gdp & Hiv/Aids & Schooling                        Gdp
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...  Thinness 1-19 Years
#
#                                                    Coefficent3  \
# Adult Mortality & Hiv/Aids & Schooling & Water         1.07399
# Birth Per Woman & Hiv/Aids & Schooling & Total ...     1.04609
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...   -0.453112
# Birth Per Woman & Gdp & Hiv/Aids & Schooling         -0.682624
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...   -0.346299
#
#                                                       Other Variable3  \
# Adult Mortality & Hiv/Aids & Schooling & Water               Hiv/Aids
# Birth Per Woman & Hiv/Aids & Schooling & Total ...  Total Expenditure
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...           Hiv/Aids
# Birth Per Woman & Gdp & Hiv/Aids & Schooling                 Hiv/Aids
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...           Hiv/Aids
#
#                                                    Coefficent4 y intercept
# Adult Mortality & Hiv/Aids & Schooling & Water        0.159142     46.8942
# Birth Per Woman & Hiv/Aids & Schooling & Total ...    0.283604     63.7115
# Adult Mortality & Birth Per Woman & Hiv/Aids & ...    0.971553      67.556
# Birth Per Woman & Gdp & Hiv/Aids & Schooling          0.926698     66.1827
# Adult Mortality & Hiv/Aids & Thinness 1-19 Year...    0.252851     53.9853

# %%
#Graphing 4Variable Regression Results

top5 = multilinear4["all"][:10]
lab = top5.index
y = np.arange(len(lab))
width = 0.35
fig, ax = plt.subplots(figsize=(10, 5))
rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
ax.set_ylabel('Variables')
ax.set_title(f' Multilinear Regression with 4 Variables')
ax.set_yticks(y)
ax.set_yticklabels(lab)
ax.legend()
plt.tight_layout()
plt.savefig(f'images/all4.png')

# %% [markdown]
# # Health Vs NonHealth Variables

# %%
#Use if want to filter for type of variable
#cols[0] for health variables 
#cols[1] for non-health variables
cols = []
labels = ["health","nonhealth"]
cols.append(['Country', 'Year', 'Life Expectancy', 'Adult Mortality', 'Infant Deaths','Hepatitis B','Measles', 'Bmi', 'Under-Five Deaths', 'Polio','Diphtheria', 'Hiv/Aids', 'Thinness 1-19 Years','Thinness 5-9 Years'])
cols.append(['Country', 'Year', 'Life Expectancy', 'Alcohol', 'Percentage Expenditure', 'Total Expenditure','Gdp', 'Population', 'Schooling','Fdi', 'Birth Per Woman', 'Water', 'Military', 'Status Developed'])
print(cols[1])
# Out:
# ['Country', 'Year', 'Life Expectancy', 'Alcohol', 'Percentage Expenditure', 'Total Expenditure', 'Gdp', 'Population', 'Schooling', 'Fdi', 'Birth Per Woman', 'Water', 'Military', 'Status Developed']

# %%
#linear regression with variables
for col in range(len(cols)):
    results ={}
    others = cols[col][3:]
    for value in others:
        fewdata = alldata[["Country","Year","Life Expectancy",value]].copy()
        X = fewdata[[value]]
        y = fewdata["Life Expectancy"].values.reshape(-1, 1)

        #Split Data into Train and Test
        X_train, X_test, y_train, y_test = train_test_split(X, y)

        model = LinearRegression()

        model.fit(X_train, y_train)
        training_score = model.score(X_train, y_train)
        testing_score = model.score(X_test, y_test)

        results[value] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0], "y intercept": model.intercept_[0]} 
        scores = pd.DataFrame(results)
        scores=scores.transpose().sort_values(by=['Training Score'], ascending=False)
        linear1[labels[col]]=scores
linear1["health"].head()
# Out:
#                     Training Score Testing Score             Variable  \
# Adult Mortality           0.523751      0.561673      Adult Mortality
# Hiv/Aids                  0.372096      0.401039             Hiv/Aids
# Bmi                       0.311883      0.373317                  Bmi
# Thinness 5-9 Years        0.250066      0.251167   Thinness 5-9 Years
# Thinness 1-19 Years       0.226627      0.294621  Thinness 1-19 Years
#
#                     Coefficent y intercept
# Adult Mortality     -0.0522715     78.6086
# Hiv/Aids              -1.05598     71.8756
# Bmi                   0.254918     60.2371
# Thinness 5-9 Years    -1.00879     74.6373
# Thinness 1-19 Years  -0.923447     74.3407

# %%
linear1["nonhealth"].head()
# Out:
#                  Training Score Testing Score          Variable   Coefficent  \
# Water                  0.643574      0.595823             Water     0.399478
# Birth Per Woman        0.626184      0.607222   Birth Per Woman     -4.90235
# Schooling              0.562552      0.500244         Schooling       2.4174
# Gdp                    0.209222      0.156626               Gdp  0.000331281
# Status Developed       0.207837      0.180332  Status Developed       10.782
#
#                  y intercept
# Water                36.2263
# Birth Per Woman      84.0809
# Schooling            40.0436
# Gdp                  67.6408
# Status Developed     67.9659

# %%
#Graphing 1Variable Regression Results
for label in labels:
    top5 = linear1[label][:5]
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Linear Regression {label.title()} Variables')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}1.png')

# %%
#multilinear regression with 2 variables
for col in range(len(cols)):
    resultstoo ={}
    others = cols[col][3:]
    for o1 in range(len(others)-1):
        value=others[o1]
        otherstoo = others[1:]
        for other in otherstoo:
            fewdata = alldata[["Country","Year","Life Expectancy",value, other]].copy()
            if value != other:
                theX = [value, other]
                theX.sort()
                X = fewdata[theX]
                y = fewdata["Life Expectancy"].values.reshape(-1, 1)

                #Split Data into Train and Test
                X_train, X_test, y_train, y_test = train_test_split(X, y)

                model = LinearRegression()

                model.fit(X_train, y_train)
                training_score = model.score(X_train, y_train)
                testing_score = model.score(X_test, y_test)

                resultstoo[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1], "y intercept": model.intercept_[0]} 
    scorestoo = pd.DataFrame(resultstoo)
    scorestoo=scorestoo.transpose().sort_values(by=['Training Score'], ascending=False)
    multilinear2[labels[col]]=scorestoo
multilinear2["health"].head()
# Out:
#                                       Training Score Testing Score  \
# Adult Mortality & Thinness 1-19 Years       0.644193      0.547356
# Adult Mortality & Bmi                        0.63807      0.641348
# Adult Mortality & Thinness 5-9 Years        0.634939      0.557513
# Adult Mortality & Diphtheria                0.600528      0.538246
# Bmi & Hiv/Aids                              0.580026      0.539057
#
#                                               Variable Coefficent  \
# Adult Mortality & Thinness 1-19 Years  Adult Mortality -0.0457338
# Adult Mortality & Bmi                  Adult Mortality -0.0414559
# Adult Mortality & Thinness 5-9 Years   Adult Mortality -0.0455965
# Adult Mortality & Diphtheria           Adult Mortality -0.0473573
# Bmi & Hiv/Aids                                Hiv/Aids   0.208143
#
#                                             Other Variable Coefficent2  \
# Adult Mortality & Thinness 1-19 Years  Thinness 1-19 Years   -0.609413
# Adult Mortality & Bmi                                  Bmi    0.170786
# Adult Mortality & Thinness 5-9 Years    Thinness 5-9 Years   -0.576307
# Adult Mortality & Diphtheria                    Diphtheria    0.104768
# Bmi & Hiv/Aids                                         Bmi   -0.909589
#
#                                       y intercept
# Adult Mortality & Thinness 1-19 Years     80.3288
# Adult Mortality & Bmi                     69.9836
# Adult Mortality & Thinness 5-9 Years      80.1582
# Adult Mortality & Diphtheria              68.8593
# Bmi & Hiv/Aids                            63.6107

# %%
multilinear2["nonhealth"].head()
# Out:
#                                Training Score Testing Score         Variable  \
# Birth Per Woman & Schooling          0.675634      0.655707  Birth Per Woman
# Birth Per Woman & Water              0.665584      0.708773            Water
# Percentage Expenditure & Water        0.66551      0.662254            Water
# Status Developed & Water              0.66432      0.643341            Water
# Gdp & Water                          0.661211      0.676669            Water
#
#                                  Coefficent          Other Variable  \
# Birth Per Woman & Schooling        -3.38247               Schooling
# Birth Per Woman & Water            -2.43469         Birth Per Woman
# Percentage Expenditure & Water  0.000883387  Percentage Expenditure
# Status Developed & Water            3.96781        Status Developed
# Gdp & Water                     0.000141277                     Gdp
#
#                                Coefficent2 y intercept
# Birth Per Woman & Schooling        1.01046     66.8727
# Birth Per Woman & Water           0.222127     58.0643
# Percentage Expenditure & Water    0.362451     38.5644
# Status Developed & Water          0.369597     38.0476
# Gdp & Water                       0.356719     38.8929

# %%
#Graphing 2Variable Regression Results
for label in labels:
    top5 = multilinear2[label][:5]
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Multilinear Regression with 2 {label.title()} Variables')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}2.png')

# %%
#multilinear regression with 3 variables
for col in range(len(cols)):
    others = cols[col][3:]
    resultsthree ={}
    for o1 in range(len(others)-2):
            value=others[o1]
            otherstoo = others[1:]
            for o2 in range(len(otherstoo)-1):
                other=otherstoo[o2+1]
                othersthree = otherstoo[1:]
                for other2 in othersthree:
                    fewdata = alldata[["Country","Year","Life Expectancy",value, other, other2]].copy()
                    if (value != other) and (value != other2) and (other2 != other):
                        theX = [value, other, other2]
                        theX.sort()
                        X = fewdata[theX]
                        y = fewdata["Life Expectancy"].values.reshape(-1, 1)

                        #Split Data into Train and Test
                        X_train, X_test, y_train, y_test = train_test_split(X, y)

                        model = LinearRegression()
                        model.fit(X_train, y_train)
                        training_score = model.score(X_train, y_train)
                        testing_score = model.score(X_test, y_test)

                        resultsthree[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1],"Other Variable2":other2,f"Coefficent3": model.coef_[0][2], "y intercept": model.intercept_[0]} 
    scoresthree = pd.DataFrame(resultsthree)
    scoresthree= scoresthree.transpose().sort_values(by=['Training Score'], ascending=False)
    multilinear3[labels[col]]=scoresthree
multilinear3["health"].head()
# Out:
#                                                  Training Score Testing Score  \
# Adult Mortality & Bmi & Hiv/Aids                       0.674755      0.679041
# Adult Mortality & Bmi & Diphtheria                     0.671561      0.663193
# Adult Mortality & Bmi & Thinness 1-19 Years            0.660875       0.68111
# Adult Mortality & Bmi & Hepatitis B                    0.655021       0.61786
# Adult Mortality & Hiv/Aids & Thinness 1-19 Years       0.653986       0.65198
#
#                                                          Variable Coefficent  \
# Adult Mortality & Bmi & Hiv/Aids                  Adult Mortality -0.0303196
# Adult Mortality & Bmi & Diphtheria                Adult Mortality -0.0409645
# Adult Mortality & Bmi & Thinness 1-19 Years       Adult Mortality -0.0412062
# Adult Mortality & Bmi & Hepatitis B               Adult Mortality -0.0422304
# Adult Mortality & Hiv/Aids & Thinness 1-19 Years  Adult Mortality -0.0360564
#
#                                                        Other Variable  \
# Adult Mortality & Bmi & Hiv/Aids                             Hiv/Aids
# Adult Mortality & Bmi & Diphtheria                         Diphtheria
# Adult Mortality & Bmi & Thinness 1-19 Years       Thinness 1-19 Years
# Adult Mortality & Bmi & Hepatitis B                               Bmi
# Adult Mortality & Hiv/Aids & Thinness 1-19 Years  Thinness 1-19 Years
#
#                                                  Coefficent2 Other Variable2  \
# Adult Mortality & Bmi & Hiv/Aids                    0.164781             Bmi
# Adult Mortality & Bmi & Diphtheria                  0.146588             Bmi
# Adult Mortality & Bmi & Thinness 1-19 Years         0.115908             Bmi
# Adult Mortality & Bmi & Hepatitis B                 0.163372     Hepatitis B
# Adult Mortality & Hiv/Aids & Thinness 1-19 Years   -0.392133        Hiv/Aids
#
#                                                  Coefficent3 y intercept
# Adult Mortality & Bmi & Hiv/Aids                   -0.429337     69.3573
# Adult Mortality & Bmi & Diphtheria                 0.0757266     64.5949
# Adult Mortality & Bmi & Thinness 1-19 Years        -0.372776     74.0037
# Adult Mortality & Bmi & Hepatitis B                0.0287142     68.2744
# Adult Mortality & Hiv/Aids & Thinness 1-19 Years   -0.609295     79.4375

# %%
multilinear3["nonhealth"].head()
# Out:
#                                                  Training Score Testing Score  \
# Birth Per Woman & Percentage Expenditure & Water       0.721191      0.659774
# Birth Per Woman & Schooling & Water                    0.712314      0.671407
# Birth Per Woman & Gdp & Water                          0.704365       0.71194
# Gdp & Schooling & Water                                0.697816      0.675842
# Percentage Expenditure & Schooling & Water               0.6973       0.67871
#
#                                                                 Variable  \
# Birth Per Woman & Percentage Expenditure & Water  Percentage Expenditure
# Birth Per Woman & Schooling & Water                                Water
# Birth Per Woman & Gdp & Water                                      Water
# Gdp & Schooling & Water                                            Water
# Percentage Expenditure & Schooling & Water        Percentage Expenditure
#
#                                                    Coefficent  \
# Birth Per Woman & Percentage Expenditure & Water     -2.46052
# Birth Per Woman & Schooling & Water                  -1.81034
# Birth Per Woman & Gdp & Water                        -2.43748
# Gdp & Schooling & Water                            0.00010836
# Percentage Expenditure & Schooling & Water        0.000713613
#
#                                                    Other Variable  \
# Birth Per Woman & Percentage Expenditure & Water            Water
# Birth Per Woman & Schooling & Water               Birth Per Woman
# Birth Per Woman & Gdp & Water                     Birth Per Woman
# Gdp & Schooling & Water                                 Schooling
# Percentage Expenditure & Schooling & Water                  Water
#
#                                                   Coefficent2  \
# Birth Per Woman & Percentage Expenditure & Water  0.000886192
# Birth Per Woman & Schooling & Water                  0.728507
# Birth Per Woman & Gdp & Water                     0.000149718
# Gdp & Schooling & Water                              0.808896
# Percentage Expenditure & Schooling & Water           0.851045
#
#                                                   Other Variable2 Coefficent3  \
# Birth Per Woman & Percentage Expenditure & Water  Birth Per Woman    0.200921
# Birth Per Woman & Schooling & Water                     Schooling    0.185721
# Birth Per Woman & Gdp & Water                                 Gdp    0.193583
# Gdp & Schooling & Water                                       Gdp    0.272216
# Percentage Expenditure & Schooling & Water              Schooling    0.272767
#
#                                                  y intercept
# Birth Per Woman & Percentage Expenditure & Water     59.2937
# Birth Per Woman & Schooling & Water                   50.393
# Birth Per Woman & Gdp & Water                        59.5342
# Gdp & Schooling & Water                              36.2578
# Percentage Expenditure & Schooling & Water           35.7061

# %%
#Graphing 3Variable Regression Results
for label in labels:
    top5 = multilinear3[label][:5]
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Multilinear Regression with 3 {label.title()} Variables')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}3.png')

# %%
#multilinear regression with 4 variables
for col in range(len(cols)):
    others = cols[col][3:]
    resultsfour ={}
    for o1 in range(len(others)-3):
        value=others[o1]
        otherstoo = others[1:]
        for o2 in range(len(otherstoo)-2):
            other=otherstoo[o2+1]
            othersthree = otherstoo[1:]
            for o3 in range(len(othersthree)-1):
                other2=otherstoo[o3+2]
                othersfour = othersthree[1:]
                for other3 in othersfour:
                    fewdata = alldata[["Country","Year","Life Expectancy",value, other, other2,other3]].copy()
                    if (value != other) and (value != other2) and (other2 != other) and (value != other3) and (other3 != other2) and (other3 != other):
                        theX = [value, other,other2,other3]
                        theX.sort()
                        X = fewdata[theX]
                        y = fewdata["Life Expectancy"].values.reshape(-1, 1)

                        #Split Data into Train and Test
                        X_train, X_test, y_train, y_test = train_test_split(X, y)

                        model = LinearRegression()

                        model.fit(X_train, y_train)
                        training_score = model.score(X_train, y_train)
                        testing_score = model.score(X_test, y_test)

                        resultsfour[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score, "Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1],"Other Variable2":other2,f"Coefficent3": model.coef_[0][2],"Other Variable3":other3,f"Coefficent4": model.coef_[0][3], "y intercept": model.intercept_[0]} 
    scoresfour = pd.DataFrame(resultsfour)
    scoresfour = scoresfour.transpose().sort_values(by=['Training Score'], ascending=False)
    multilinear4[labels[col]]=scoresfour
multilinear4["health"].head()
# Out:
#                                                    Training Score  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...       0.705406
# Adult Mortality & Bmi & Hiv/Aids & Polio                 0.701553
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years        0.70118
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids            0.697537
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...       0.697407
#
#                                                    Testing Score  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...      0.687574
# Adult Mortality & Bmi & Hiv/Aids & Polio                 0.67914
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years      0.619136
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids           0.715912
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...      0.698842
#
#                                                            Variable  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...  Adult Mortality
# Adult Mortality & Bmi & Hiv/Aids & Polio            Adult Mortality
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years  Adult Mortality
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids       Adult Mortality
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...  Adult Mortality
#
#                                                    Coefficent  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...  -0.030636
# Adult Mortality & Bmi & Hiv/Aids & Polio           -0.0301339
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years -0.0396744
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids      -0.0300025
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9... -0.0299076
#
#                                                          Other Variable  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...  Thinness 1-19 Years
# Adult Mortality & Bmi & Hiv/Aids & Polio                       Hiv/Aids
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years                Polio
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids                  Hiv/Aids
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...             Hiv/Aids
#
#                                                    Coefficent2  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...    0.126008
# Adult Mortality & Bmi & Hiv/Aids & Polio              0.147366
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years    0.110171
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids         0.148514
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...    0.122661
#
#                                                        Other Variable2  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...            Hiv/Aids
# Adult Mortality & Bmi & Hiv/Aids & Polio                         Polio
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years  Thinness 5-9 Years
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids               Diphtheria
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...  Thinness 5-9 Years
#
#                                                    Coefficent3  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...   -0.404227
# Adult Mortality & Bmi & Hiv/Aids & Polio             -0.398314
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years   0.0611022
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids        0.0658877
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...   -0.410372
#
#                                                    Other Variable3  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...             Bmi
# Adult Mortality & Bmi & Hiv/Aids & Polio                       Bmi
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years             Bmi
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids                  Bmi
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...             Bmi
#
#                                                    Coefficent4 y intercept
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...   -0.339717     72.4307
# Adult Mortality & Bmi & Hiv/Aids & Polio             0.0624165     64.7238
# Adult Mortality & Bmi & Polio & Thinness 5-9 Years   -0.304948      68.637
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids        -0.414562     64.3672
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...   -0.307031     72.4069

# %%
multilinear4["nonhealth"].head()
# Out:
#                                                    Training Score  \
# Birth Per Woman & Gdp & Schooling & Water                  0.7299
# Birth Per Woman & Gdp & Total Expenditure & Water        0.727832
# Birth Per Woman & Gdp & Military & Water                 0.726874
# Birth Per Woman & Schooling & Total Expenditure...       0.722587
# Birth Per Woman & Fdi & Gdp & Water                      0.719408
#
#                                                    Testing Score  \
# Birth Per Woman & Gdp & Schooling & Water               0.675432
# Birth Per Woman & Gdp & Total Expenditure & Water       0.660317
# Birth Per Woman & Gdp & Military & Water                0.637464
# Birth Per Woman & Schooling & Total Expenditure...      0.639184
# Birth Per Woman & Fdi & Gdp & Water                     0.673362
#
#                                                            Variable  \
# Birth Per Woman & Gdp & Schooling & Water           Birth Per Woman
# Birth Per Woman & Gdp & Total Expenditure & Water   Birth Per Woman
# Birth Per Woman & Gdp & Military & Water            Birth Per Woman
# Birth Per Woman & Schooling & Total Expenditure...  Birth Per Woman
# Birth Per Woman & Fdi & Gdp & Water                 Birth Per Woman
#
#                                                    Coefficent  \
# Birth Per Woman & Gdp & Schooling & Water            -1.96487
# Birth Per Woman & Gdp & Total Expenditure & Water    -2.24996
# Birth Per Woman & Gdp & Military & Water             -2.42563
# Birth Per Woman & Schooling & Total Expenditure...   -1.97708
# Birth Per Woman & Fdi & Gdp & Water                  -2.37694
#
#                                                        Other Variable  \
# Birth Per Woman & Gdp & Schooling & Water                       Water
# Birth Per Woman & Gdp & Total Expenditure & Water   Total Expenditure
# Birth Per Woman & Gdp & Military & Water                     Military
# Birth Per Woman & Schooling & Total Expenditure...  Total Expenditure
# Birth Per Woman & Fdi & Gdp & Water                             Water
#
#                                                     Coefficent2  \
# Birth Per Woman & Gdp & Schooling & Water           9.58548e-05
# Birth Per Woman & Gdp & Total Expenditure & Water    0.00015314
# Birth Per Woman & Gdp & Military & Water            0.000133412
# Birth Per Woman & Schooling & Total Expenditure...     0.737799
# Birth Per Woman & Fdi & Gdp & Water                  0.00919824
#
#                                                    Other Variable2  \
# Birth Per Woman & Gdp & Schooling & Water                Schooling
# Birth Per Woman & Gdp & Total Expenditure & Water            Water
# Birth Per Woman & Gdp & Military & Water                     Water
# Birth Per Woman & Schooling & Total Expenditure...           Water
# Birth Per Woman & Fdi & Gdp & Water                            Fdi
#
#                                                    Coefficent3  \
# Birth Per Woman & Gdp & Schooling & Water             0.554732
# Birth Per Woman & Gdp & Total Expenditure & Water     0.263351
# Birth Per Woman & Gdp & Military & Water             0.0195163
# Birth Per Woman & Schooling & Total Expenditure...     0.19192
# Birth Per Woman & Fdi & Gdp & Water                 0.00013441
#
#                                                    Other Variable3  \
# Birth Per Woman & Gdp & Schooling & Water                      Gdp
# Birth Per Woman & Gdp & Total Expenditure & Water              Gdp
# Birth Per Woman & Gdp & Military & Water                       Gdp
# Birth Per Woman & Schooling & Total Expenditure...       Schooling
# Birth Per Woman & Fdi & Gdp & Water                            Gdp
#
#                                                    Coefficent4 y intercept
# Birth Per Woman & Gdp & Schooling & Water             0.174895     53.3554
# Birth Per Woman & Gdp & Total Expenditure & Water     0.201854     56.8553
# Birth Per Woman & Gdp & Military & Water              0.202874      58.945
# Birth Per Woman & Schooling & Total Expenditure...    0.175981     50.3183
# Birth Per Woman & Fdi & Gdp & Water                   0.201419     58.8162

# %%
#Graphing 4Variable Regression Results
for label in labels:
    top5 = multilinear4[label][:5]
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Multilinear Regression with 4 {label.title()} Variables')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}4.png')

# %% [markdown]
# # Developed Vs Developing Countries

# %%
#Create a Developing Dataset and Developed Dataset
developed = alldata.copy().rename(columns={"Status Developed":"Developed"})
developed = developed[developed.columns[1:]]
developing = alldata.copy()
developing["Status Developed"] = developing["Status Developed"].replace(0, 2).replace(1, 0).replace(2, 1)
developing = developing.rename(columns={"Status Developed":"Developing"})
developing = developing[developing.columns[1:]]
datasets = [developed, developing]
labels = ["Developed", "Developing"]

#Split Dataset into Developing and Developed Countries
developed = developed.drop(x for x in developed["Developed"].index if developed.loc[x]["Developed"] == 0)
developed = developed[developed.columns[:-1]]
developing = developing.drop(x for x in developing["Developing"].index if developing.loc[x]["Developing"] == 0)
developing = developing[developing.columns[:-1]]
developing.head()
# Out:
#        Country  Year  Life Expectancy  Adult Mortality  Infant Deaths  \
# 0  afghanistan  2015             65.0            263.0             62
# 1  afghanistan  2014             59.9            271.0             64
# 2  afghanistan  2013             59.9            268.0             66
# 3  afghanistan  2012             59.5            272.0             69
# 4  afghanistan  2011             59.2            275.0             71
#
#    Alcohol  Percentage Expenditure  Hepatitis B  Measles   Bmi  ...  Hiv/Aids  \
# 0     0.01               71.279624         65.0     1154  19.1  ...       0.1
# 1     0.01               73.523582         62.0      492  18.6  ...       0.1
# 2     0.01               73.219243         64.0      430  18.1  ...       0.1
# 3     0.01               78.184215         67.0     2787  17.6  ...       0.1
# 4     0.01                7.097109         68.0     3013  17.2  ...       0.1
#
#           Gdp  Population  Thinness 1-19 Years  Thinness 5-9 Years  Schooling  \
# 0  584.259210  33736494.0                 17.2                17.3       10.1
# 1  612.696514    327582.0                 17.5                17.5       10.0
# 2  631.744976  31731688.0                 17.7                17.7        9.9
# 3  669.959000   3696958.0                 17.9                18.0        9.8
# 4   63.537231   2978599.0                 18.2                18.2        9.5
#
#         Fdi  Birth Per Woman  Water  Military
# 0  0.849679             4.80   61.5  0.993455
# 1  0.209790             4.98   58.8  1.298013
# 2  0.234965             5.17   56.2  1.076950
# 3  0.284095             5.38   53.5  1.175417
# 4  0.293039             5.60   50.9  1.821346
#
# [5 rows x 24 columns]

# %%
#Creating Labels and columns list
datasets = [developed, developing]
labels = ["developed", "developing"]

# %%
#Linear regression 
regress1=[]
for index in range(len(datasets)):
    label = labels[index]
    results ={}
    for value in alldata.columns[4:]:
        #Choose columns
        fewdata = alldata[["Country","Year","Life Expectancy",value]].copy()
        X = fewdata[value].values.reshape(-1, 1)
        y = fewdata["Life Expectancy"].values.reshape(-1, 1)

        #Split Data into Train and Test
        X_train, X_test, y_train, y_test = train_test_split(X, y)

        model = LinearRegression()

        model.fit(X_train, y_train)
        training_score = model.score(X_train, y_train)
        testing_score = model.score(X_test, y_test)

        results[value] = {"Training Score":training_score,"Testing Score": testing_score, "Coefficent": model.coef_[0][0], "y intercept": model.intercept_[0]} 
    scores = pd.DataFrame(results)
    scores = scores.transpose().sort_values(by=['Training Score'], ascending=False)
    regress1.append(scores)
    linear1[labels[index]] = scores
linear1["developing"]
# Out:
#                         Training Score  Testing Score    Coefficent  \
# Water                         0.638402       0.604265  3.954771e-01
# Birth Per Woman               0.629016       0.603717 -4.810612e+00
# Schooling                     0.558806       0.513737  2.404271e+00
# Adult Mortality               0.526623       0.556094 -5.180311e-02
# Hiv/Aids                      0.385457       0.355967 -1.027649e+00
# Bmi                           0.327452       0.328492  2.645450e-01
# Thinness 5-9 Years            0.256164       0.231197 -1.013172e+00
# Thinness 1-19 Years           0.253327       0.225934 -1.027825e+00
# Alcohol                       0.213867       0.063234  1.030333e+00
# Gdp                           0.210253       0.149646  3.528704e-04
# Status Developed              0.195602       0.218533  1.061545e+01
# Percentage Expenditure        0.180716       0.141511  2.061751e-03
# Diphtheria                    0.131940       0.210551  1.563282e-01
# Polio                         0.129852       0.121884  1.490487e-01
# Hepatitis B                   0.051789       0.048026  8.102447e-02
# Under-Five Deaths             0.043260       0.044733 -1.061900e-02
# Infant Deaths                 0.034585       0.041248 -1.187306e-02
# Total Expenditure             0.031351       0.042385  7.085325e-01
# Fdi                           0.011166       0.020897  4.253978e-02
# Measles                       0.005258       0.013289 -6.433764e-05
# Population                    0.001725      -0.019903 -4.936462e-09
# Military                      0.000131      -0.001370 -8.401592e-02
#
#                         y intercept
# Water                     36.304065
# Birth Per Woman           83.757031
# Schooling                 40.190528
# Adult Mortality           78.520283
# Hiv/Aids                  71.736646
# Bmi                       59.612771
# Thinness 5-9 Years        74.583195
# Thinness 1-19 Years       74.671609
# Alcohol                   64.850694
# Gdp                       67.728905
# Status Developed          68.113121
# Percentage Expenditure    68.296136
# Diphtheria                56.643070
# Polio                     57.536844
# Hepatitis B               63.357071
# Under-Five Deaths         70.211038
# Infant Deaths             70.335397
# Total Expenditure         65.544185
# Fdi                       69.533995
# Measles                   70.107421
# Population                69.682436
# Military                  70.162349

# %%
#Graphing Single Regression Results
for label in labels:
    lab = linear1[label].index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 10))
    rects1 = ax.barh(y - width/2, linear1[label]["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, linear1[label]["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f'Linear Regression for {label.title()} Countries')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/linear1{label}.png')

# %%
#multilinear regression with 2 variables
for index in range(len(datasets)):
    label = labels[index]
    resultstoo ={}
    others = list(datasets[index].columns[3:])
    for o1 in range(len(others)-1):
        value=others[o1]
        otherstoo = others[1:]
        for other in otherstoo:
            fewdata = alldata[["Country","Year","Life Expectancy",value, other]].copy()
            if (value != other):
                theX = [value, other]
                theX.sort()
                X = fewdata[theX]
                y = fewdata["Life Expectancy"].values.reshape(-1, 1)

                #Split Data into Train and Test
                X_train, X_test, y_train, y_test = train_test_split(X, y)

                model = LinearRegression()

                model.fit(X_train, y_train)
                training_score = model.score(X_train, y_train)
                testing_score = model.score(X_test, y_test)

                resultstoo[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1], "y intercept": model.intercept_[0]} 
    scorestoo = pd.DataFrame(resultstoo)
    scorestoo = scorestoo.transpose().sort_values(by=['Training Score'], ascending=False)
    multilinear2[labels[index]] = scorestoo
multilinear2["developing"]
# Out:
#                                   Training Score Testing Score  \
# Adult Mortality & Birth Per Woman       0.764983      0.778513
# Hiv/Aids & Water                        0.764689      0.745575
# Adult Mortality & Water                 0.761437      0.781149
# Birth Per Woman & Hiv/Aids              0.755981      0.781191
# Hiv/Aids & Schooling                    0.747882      0.763393
# ...                                          ...           ...
# Fdi & Military                         0.0167821    0.00416795
# Fdi & Population                       0.0127088     0.0199492
# Measles & Military                     0.0094312   -0.00284521
# Measles & Population                  0.00857311    0.00460286
# Military & Population                 0.00370792   -0.00734093
#
#                                           Variable   Coefficent  \
# Adult Mortality & Birth Per Woman  Adult Mortality     -0.03252
# Hiv/Aids & Water                             Water    -0.672243
# Adult Mortality & Water            Adult Mortality   -0.0301176
# Birth Per Woman & Hiv/Aids         Birth Per Woman     -4.01794
# Hiv/Aids & Schooling                     Schooling    -0.785977
# ...                                            ...          ...
# Fdi & Military                                 Fdi    0.0461085
# Fdi & Population                               Fdi    0.0399178
# Measles & Military                         Measles -8.78107e-05
# Measles & Population                    Population -7.18698e-05
# Military & Population                   Population    -0.229014
#
#                                     Other Variable  Coefficent2 y intercept
# Adult Mortality & Birth Per Woman  Birth Per Woman     -3.47088     85.2296
# Hiv/Aids & Water                          Hiv/Aids      0.32633     43.6654
# Adult Mortality & Water                      Water     0.283219     51.0472
# Birth Per Woman & Hiv/Aids                Hiv/Aids    -0.677956     82.5788
# Hiv/Aids & Schooling                      Hiv/Aids      2.02181     46.3944
# ...                                            ...          ...         ...
# Fdi & Military                            Military   -0.0698498     69.6313
# Fdi & Population                        Population  -2.3603e-09     69.6278
# Measles & Military                        Military    -0.101148     70.4416
# Measles & Population                       Measles -7.72721e-10     70.0922
# Military & Population                     Military -5.38332e-09     70.4888
#
# [210 rows x 7 columns]

# %%
#Graphing 4Variable Regression Results
for label in labels:
    top5 = multilinear2[label][:5]
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Multilinear Regression with 2 Variables ({label.title()} Countries)')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}2.png')

# %%
#multilinear regression with 3 variables
for index in range(len(datasets)):
    label = labels[index]
    resultsthree ={}
    others = list(datasets[index].columns[3:])
    for o1 in range(len(others)-2):
        value=others[o1]
        otherstoo = others[1:]
        for o2 in range(len(otherstoo)-1):
            other=otherstoo[o2+1]
            othersthree = otherstoo[1:]
            for other2 in othersthree:
                fewdata = alldata[["Country","Year","Life Expectancy",value, other, other2]].copy()
                if (value != other) and (value != other2) and (other2 != other):
                    theX = [value, other,other2]
                    theX.sort()
                    X = fewdata[theX]
                    y = fewdata["Life Expectancy"].values.reshape(-1,1)

                    #Split Data into Train and Test
                    X_train, X_test, y_train, y_test = train_test_split(X, y)

                    model = LinearRegression()

                    model.fit(X_train, y_train)
                    training_score = model.score(X_train, y_train)
                    testing_score = model.score(X_test, y_test)

                    resultsthree[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1],"Other Variable2":other2,f"Coefficent3": model.coef_[0][2], "y intercept": model.intercept_[0]} 
    scoresthree = pd.DataFrame(resultsthree)
    scoresthree=scoresthree.transpose().sort_values(by=['Training Score'], ascending=False)
    multilinear3[labels[index]]=scoresthree
multilinear3["developing"].head()
# Out:
#                                              Training Score Testing Score  \
# Hiv/Aids & Schooling & Water                       0.819674      0.801887
# Birth Per Woman & Hiv/Aids & Schooling             0.817961      0.805292
# Adult Mortality & Birth Per Woman & Hiv/Aids       0.811568      0.771052
# Hiv/Aids & Percentage Expenditure & Water          0.803707       0.76017
# Adult Mortality & Thinness 5-9 Years & Water       0.802486       0.77509
#
#                                                      Variable Coefficent  \
# Hiv/Aids & Schooling & Water                        Schooling  -0.676026
# Birth Per Woman & Hiv/Aids & Schooling        Birth Per Woman   -2.32179
# Adult Mortality & Birth Per Woman & Hiv/Aids  Adult Mortality -0.0240482
# Hiv/Aids & Percentage Expenditure & Water            Hiv/Aids  -0.683073
# Adult Mortality & Thinness 5-9 Years & Water  Adult Mortality -0.0286149
#
#                                                Other Variable  Coefficent2  \
# Hiv/Aids & Schooling & Water                            Water      1.10893
# Birth Per Woman & Hiv/Aids & Schooling              Schooling    -0.667975
# Adult Mortality & Birth Per Woman & Hiv/Aids  Birth Per Woman     -3.33494
# Hiv/Aids & Percentage Expenditure & Water               Water  0.000868977
# Adult Mortality & Thinness 5-9 Years & Water            Water     -0.39174
#
#                                                      Other Variable2  \
# Hiv/Aids & Schooling & Water                                Hiv/Aids
# Birth Per Woman & Hiv/Aids & Schooling                      Hiv/Aids
# Adult Mortality & Birth Per Woman & Hiv/Aids                Hiv/Aids
# Hiv/Aids & Percentage Expenditure & Water     Percentage Expenditure
# Adult Mortality & Thinness 5-9 Years & Water      Thinness 5-9 Years
#
#                                              Coefficent3 y intercept
# Hiv/Aids & Schooling & Water                    0.194309      41.034
# Birth Per Woman & Hiv/Aids & Schooling           1.16273     63.3499
# Adult Mortality & Birth Per Woman & Hiv/Aids   -0.342781     84.1746
# Hiv/Aids & Percentage Expenditure & Water       0.301272     45.0697
# Adult Mortality & Thinness 5-9 Years & Water    0.261505     54.4089

# %%
#Graphing 3Variable Regression Results
for label in labels:
    top5 = multilinear3[label][:5]
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Multilinear Regression with 3 Variables ({label.title()} Countries)')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}3.png')

# %%
#multilinear regression with 4 variables
for index in range(len(datasets)):
    label = labels[index]
    resultsfour ={}
    others = list(datasets[index].columns[3:])
    for o1 in range(len(others)-3):
        value=others[o1]
        otherstoo = others[1:]
        for o2 in range(len(otherstoo)-2):
            other=otherstoo[o2+1]
            othersthree = otherstoo[1:]
            for o3 in range(len(othersthree)-1):
                other=otherstoo[o3+2]
                othersfour = othersthree[1:]
                for other3 in othersfour:
                    fewdata = alldata[["Country","Year","Life Expectancy",value, other, other2,other3]].copy().dropna(how="any")
                    if (value != other) and (value != other2) and (other2 != other) and (value != other3) and (other3 != other2) and (other3 != other):
                        theX = [value, other,other2,other3]
                        theX.sort()
                        X = fewdata[theX]
                        y = fewdata["Life Expectancy"].values.reshape(-1, 1)

                        #Split Data into Train and Test
                        X_train, X_test, y_train, y_test = train_test_split(X, y)

                        model = LinearRegression()

                        model.fit(X_train, y_train)
                        training_score = model.score(X_train, y_train)
                        testing_score = model.score(X_test, y_test)

                        resultsfour[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score, "Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1],"Other Variable2":other2,f"Coefficent3": model.coef_[0][2],"Other Variable3":other3,f"Coefficent4": model.coef_[0][3], "y intercept": model.intercept_[0]} 
    scoresfour = pd.DataFrame(resultsfour)
    scoresfour =scoresfour.transpose().sort_values(by=['Training Score'], ascending=False)
    multilinear4[labels[index]] = scoresfour
multilinear4["developing"].head()
# Out:
#                                                    Training Score  \
# Birth Per Woman & Hiv/Aids & Military & Schooling        0.822101
# Hiv/Aids & Military & Schooling & Water                  0.818671
# Adult Mortality & Hiv/Aids & Military & Schooling        0.817241
# Birth Per Woman & Hiv/Aids & Military & Percent...       0.809616
# Birth Per Woman & Gdp & Hiv/Aids & Military              0.805479
#
#                                                    Testing Score  \
# Birth Per Woman & Hiv/Aids & Military & Schooling       0.796595
# Hiv/Aids & Military & Schooling & Water                 0.801387
# Adult Mortality & Hiv/Aids & Military & Schooling       0.743128
# Birth Per Woman & Hiv/Aids & Military & Percent...      0.764431
# Birth Per Woman & Gdp & Hiv/Aids & Military             0.790314
#
#                                                            Variable  \
# Birth Per Woman & Hiv/Aids & Military & Schooling         Schooling
# Hiv/Aids & Military & Schooling & Water                   Schooling
# Adult Mortality & Hiv/Aids & Military & Schooling   Adult Mortality
# Birth Per Woman & Hiv/Aids & Military & Percent...         Hiv/Aids
# Birth Per Woman & Gdp & Hiv/Aids & Military                     Gdp
#
#                                                    Coefficent  \
# Birth Per Woman & Hiv/Aids & Military & Schooling    -2.41112
# Hiv/Aids & Military & Schooling & Water             -0.667373
# Adult Mortality & Hiv/Aids & Military & Schooling  -0.0220482
# Birth Per Woman & Hiv/Aids & Military & Percent...   -3.75124
# Birth Per Woman & Gdp & Hiv/Aids & Military          -3.53614
#
#                                                      Other Variable  \
# Birth Per Woman & Hiv/Aids & Military & Schooling   Birth Per Woman
# Hiv/Aids & Military & Schooling & Water                       Water
# Adult Mortality & Hiv/Aids & Military & Schooling         Schooling
# Birth Per Woman & Hiv/Aids & Military & Percent...  Birth Per Woman
# Birth Per Woman & Gdp & Hiv/Aids & Military         Birth Per Woman
#
#                                                     Coefficent2  \
# Birth Per Woman & Hiv/Aids & Military & Schooling     -0.670984
# Hiv/Aids & Military & Schooling & Water                0.130608
# Adult Mortality & Hiv/Aids & Military & Schooling     -0.492418
# Birth Per Woman & Hiv/Aids & Military & Percent...    -0.665163
# Birth Per Woman & Gdp & Hiv/Aids & Military         0.000147103
#
#                                                    Other Variable2  \
# Birth Per Woman & Hiv/Aids & Military & Schooling         Military
# Hiv/Aids & Military & Schooling & Water                   Military
# Adult Mortality & Hiv/Aids & Military & Schooling         Military
# Birth Per Woman & Hiv/Aids & Military & Percent...        Military
# Birth Per Woman & Gdp & Hiv/Aids & Military               Military
#
#                                                    Coefficent3  \
# Birth Per Woman & Hiv/Aids & Military & Schooling     0.247579
# Hiv/Aids & Military & Schooling & Water                1.20204
# Adult Mortality & Hiv/Aids & Military & Schooling    0.0787859
# Birth Per Woman & Hiv/Aids & Military & Percent...    0.221029
# Birth Per Woman & Gdp & Hiv/Aids & Military          -0.699763
#
#                                                            Other Variable3  \
# Birth Per Woman & Hiv/Aids & Military & Schooling                 Hiv/Aids
# Hiv/Aids & Military & Schooling & Water                           Hiv/Aids
# Adult Mortality & Hiv/Aids & Military & Schooling                 Hiv/Aids
# Birth Per Woman & Hiv/Aids & Military & Percent...  Percentage Expenditure
# Birth Per Woman & Gdp & Hiv/Aids & Military                       Hiv/Aids
#
#                                                     Coefficent4 y intercept
# Birth Per Woman & Hiv/Aids & Military & Schooling       1.18427     62.8918
# Hiv/Aids & Military & Schooling & Water                0.181888     40.6504
# Adult Mortality & Hiv/Aids & Military & Schooling        1.7103     53.1422
# Birth Per Woman & Hiv/Aids & Military & Percent...  0.000930445     80.5304
# Birth Per Woman & Gdp & Hiv/Aids & Military            0.191316     79.9815

# %%
#Graphing 4Variable Regression Results
for label in labels:
    top5 = multilinear4[label][:5]
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Multilinear Regression with 4 Variables ({label.title()} Countries)')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}4.png')

# %% [markdown]
# # Developed Vs Developing Countries For Different Factors

# %%
labels = ["health","nonhealth"]
datalabels = ["developed", "developing"]
thelabels = ["health_developed","health_developing","nonhealth_developed","nonhealth_developing"]
cols = []
cols.append(['Country', 'Year', 'Life Expectancy', 'Adult Mortality', 'Infant Deaths','Hepatitis B','Measles', 'Bmi', 'Under-Five Deaths', 'Polio','Diphtheria', 'Hiv/Aids', 'Thinness 1-19 Years','Thinness 5-9 Years'])
cols.append(['Country', 'Year', 'Life Expectancy', 'Alcohol', 'Percentage Expenditure', 'Total Expenditure','Gdp', 'Population', 'Schooling','Fdi', 'Birth Per Woman', 'Water', 'Military'])
print(cols[1])
# Out:
# ['Country', 'Year', 'Life Expectancy', 'Alcohol', 'Percentage Expenditure', 'Total Expenditure', 'Gdp', 'Population', 'Schooling', 'Fdi', 'Birth Per Woman', 'Water', 'Military']

# %%
#Linear regression
for index in range(len(datasets)):
    datalabel = datalabels[index]
    for col in range(len(cols)):
        results ={}
        label = labels[col] + "_" + datalabel
        others = cols[col][3:]
        for value in others:
            fewdata = alldata[["Country","Year","Life Expectancy",value]].copy().dropna(how="any")
            X = fewdata[[value]]
            y = fewdata["Life Expectancy"].values.reshape(-1, 1)

            #Split Data into Train and Test
            X_train, X_test, y_train, y_test = train_test_split(X, y)

            model = LinearRegression()

            model.fit(X_train, y_train)
            training_score = model.score(X_train, y_train)
            testing_score = model.score(X_test, y_test)

            results[value] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0], "y intercept": model.intercept_[0]} 
            scores = pd.DataFrame(results)
            scores=scores.transpose().sort_values(by=['Training Score'], ascending=False)
            linear1[label] = scores
linear1["health_developed"].head()
# Out:
#                     Training Score Testing Score             Variable  \
# Adult Mortality            0.54907      0.486593      Adult Mortality
# Hiv/Aids                  0.377511      0.378887             Hiv/Aids
# Bmi                       0.332921      0.311886                  Bmi
# Thinness 5-9 Years        0.252067      0.245318   Thinness 5-9 Years
# Thinness 1-19 Years       0.245054      0.250929  Thinness 1-19 Years
#
#                     Coefficent y intercept
# Adult Mortality     -0.0521893     78.6392
# Hiv/Aids              -1.10705     71.9821
# Bmi                   0.265485     59.6004
# Thinness 5-9 Years   -0.977812     74.5434
# Thinness 1-19 Years  -0.989949     74.6186

# %%
#Graphing Regression Results
for label in thelabels:
    top5 = linear1[label][:5]
    titlepart = label.split("_")
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Linear Regression with A {titlepart[0].title()} Variable (for {titlepart[1].title()} Countries)')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}1.png')

# %%
#2 variable regression
for index in range(len(datasets)):
    datalabel = datalabels[index]
    for col in range(len(cols)):
        resultstoo ={}
        label = labels[col] + "_" + datalabel
        others = cols[col][3:]
        for o1 in range(len(others)-1):
            value=others[o1]
            otherstoo = others[1:]
            for other in otherstoo:
                fewdata = alldata[["Country","Year","Life Expectancy",value, other]].copy().dropna(how="any")
                if (value != other):
                    theX = [value, other]
                    theX.sort()
                    X = fewdata[theX]
                    y = fewdata["Life Expectancy"].values.reshape(-1, 1)

                    #Split Data into Train and Test
                    X_train, X_test, y_train, y_test = train_test_split(X, y)

                    model = LinearRegression()

                    model.fit(X_train, y_train)
                    training_score = model.score(X_train, y_train)
                    testing_score = model.score(X_test, y_test)

                    resultstoo[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1], "y intercept": model.intercept_[0]} 
        scorestoo = pd.DataFrame(resultstoo)
        scorestoo = scorestoo.transpose().sort_values(by=['Training Score'], ascending=False)
        multilinear2[label] = scorestoo
multilinear2["health_developed"].head()
# Out:
#                                       Training Score Testing Score  \
# Adult Mortality & Bmi                       0.653894      0.596825
# Adult Mortality & Thinness 5-9 Years        0.619839      0.603614
# Adult Mortality & Thinness 1-19 Years       0.617199      0.623392
# Adult Mortality & Hiv/Aids                  0.593589       0.49957
# Adult Mortality & Diphtheria                0.592541      0.555094
#
#                                               Variable Coefficent  \
# Adult Mortality & Bmi                  Adult Mortality -0.0434987
# Adult Mortality & Thinness 5-9 Years   Adult Mortality -0.0455788
# Adult Mortality & Thinness 1-19 Years  Adult Mortality -0.0462167
# Adult Mortality & Hiv/Aids             Adult Mortality -0.0422542
# Adult Mortality & Diphtheria           Adult Mortality -0.0482719
#
#                                             Other Variable Coefficent2  \
# Adult Mortality & Bmi                                  Bmi     0.15722
# Adult Mortality & Thinness 5-9 Years    Thinness 5-9 Years   -0.584116
# Adult Mortality & Thinness 1-19 Years  Thinness 1-19 Years   -0.590082
# Adult Mortality & Hiv/Aids                        Hiv/Aids   -0.433353
# Adult Mortality & Diphtheria                    Diphtheria   0.0995561
#
#                                       y intercept
# Adult Mortality & Bmi                     71.0505
# Adult Mortality & Thinness 5-9 Years      80.1383
# Adult Mortality & Thinness 1-19 Years      80.377
# Adult Mortality & Hiv/Aids                 77.661
# Adult Mortality & Diphtheria              69.4486

# %%
#Graphing 2 Variable Regression Results
for label in thelabels:
    top5 = multilinear2[label][:5]
    titlepart = label.split("_")
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Linear Regression with 2 {titlepart[0].title()} Variables (for {titlepart[1].title()} Countries)')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}2.png')

# %%
#3 variable regression
for index in range(len(datasets)):
    datalabel = datalabels[index]
    for col in range(len(cols)):
        resultthree ={}
        label = labels[col] + "_" + datalabel
        others = cols[col][3:]
        for o1 in range(len(others)-2):
            value=others[o1]
            otherstoo = others[1:]
            for o2 in range(len(otherstoo)-1):
                other=otherstoo[o2+1]
                othersthree = otherstoo[1:]
                for other2 in othersthree:
                    fewdata = alldata[["Country","Year","Life Expectancy",value, other, other2]].copy().dropna(how="any")
                    if (value != other) and (value != other2) and (other2 != other):
                        theX = [value, other,other2]
                        theX.sort()
                        X = fewdata[theX]
                        y = fewdata["Life Expectancy"].values.reshape(-1,1)

                        #Split Data into Train and Test
                        X_train, X_test, y_train, y_test = train_test_split(X, y)

                        model = LinearRegression()

                        model.fit(X_train, y_train)
                        training_score = model.score(X_train, y_train)
                        testing_score = model.score(X_test, y_test)

                        resultsthree[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score,"Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1],"Other Variable2":other2,f"Coefficent3": model.coef_[0][2], "y intercept": model.intercept_[0]} 
        scoresthree = pd.DataFrame(resultsthree)
        scoresthree=scoresthree.transpose().sort_values(by=['Training Score'], ascending=False)
        multilinear3[label]=scoresthree
multilinear3["health_developed"].head()
# Out:
#                                              Training Score Testing Score  \
# Hiv/Aids & Schooling & Water                       0.819674      0.801887
# Birth Per Woman & Hiv/Aids & Schooling             0.817961      0.805292
# Adult Mortality & Birth Per Woman & Hiv/Aids       0.811568      0.771052
# Hiv/Aids & Percentage Expenditure & Water          0.803707       0.76017
# Adult Mortality & Thinness 5-9 Years & Water       0.802486       0.77509
#
#                                                      Variable Coefficent  \
# Hiv/Aids & Schooling & Water                        Schooling  -0.676026
# Birth Per Woman & Hiv/Aids & Schooling        Birth Per Woman   -2.32179
# Adult Mortality & Birth Per Woman & Hiv/Aids  Adult Mortality -0.0240482
# Hiv/Aids & Percentage Expenditure & Water            Hiv/Aids  -0.683073
# Adult Mortality & Thinness 5-9 Years & Water  Adult Mortality -0.0286149
#
#                                                Other Variable  Coefficent2  \
# Hiv/Aids & Schooling & Water                            Water      1.10893
# Birth Per Woman & Hiv/Aids & Schooling              Schooling    -0.667975
# Adult Mortality & Birth Per Woman & Hiv/Aids  Birth Per Woman     -3.33494
# Hiv/Aids & Percentage Expenditure & Water               Water  0.000868977
# Adult Mortality & Thinness 5-9 Years & Water            Water     -0.39174
#
#                                                      Other Variable2  \
# Hiv/Aids & Schooling & Water                                Hiv/Aids
# Birth Per Woman & Hiv/Aids & Schooling                      Hiv/Aids
# Adult Mortality & Birth Per Woman & Hiv/Aids                Hiv/Aids
# Hiv/Aids & Percentage Expenditure & Water     Percentage Expenditure
# Adult Mortality & Thinness 5-9 Years & Water      Thinness 5-9 Years
#
#                                              Coefficent3 y intercept
# Hiv/Aids & Schooling & Water                    0.194309      41.034
# Birth Per Woman & Hiv/Aids & Schooling           1.16273     63.3499
# Adult Mortality & Birth Per Woman & Hiv/Aids   -0.342781     84.1746
# Hiv/Aids & Percentage Expenditure & Water       0.301272     45.0697
# Adult Mortality & Thinness 5-9 Years & Water    0.261505     54.4089

# %%
#Graphing 3 Variable Regression Results
for label in thelabels:
    top5 = multilinear3[label][:5]
    titlepart = label.split("_")
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Linear Regression with 3 {titlepart[0].title()} Variables (for {titlepart[1].title()} Countries)')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}3.png')

# %%
#4 variable regression
for index in range(len(datasets)):
    datalabel = datalabels[index]
    for col in range(len(cols)):
        resultsfour ={}
        label = labels[col] + "_" + datalabel
        others = cols[col][3:]
        for o1 in range(len(others)-3):
            value=others[o1]
            otherstoo = others[1:]
            for o2 in range(len(otherstoo)-2):
                other=otherstoo[o2+1]
                othersthree = otherstoo[1:]
                for o3 in range(len(othersthree)-1):
                    other2=otherstoo[o3+2]
                    othersfour = othersthree[1:]
                    for other3 in othersfour:
                        fewdata = alldata[["Country","Year","Life Expectancy",value, other, other2,other3]].copy().dropna(how="any")
                        if (value != other) and (value != other2) and (other2 != other) and (value != other3) and (other3 != other2) and (other3 != other):
                            theX = [value, other,other2,other3]
                            theX.sort()
                            X = fewdata[theX]
                            y = fewdata["Life Expectancy"].values.reshape(-1, 1)

                            #Split Data into Train and Test
                            X_train, X_test, y_train, y_test = train_test_split(X, y)

                            model = LinearRegression()

                            model.fit(X_train, y_train)
                            training_score = model.score(X_train, y_train)
                            testing_score = model.score(X_test, y_test)

                            resultsfour[" & ".join(theX)] = {"Training Score":training_score,"Testing Score": testing_score, "Variable":value, f"Coefficent": model.coef_[0][0],"Other Variable":other,f"Coefficent2": model.coef_[0][1],"Other Variable2":other2,f"Coefficent3": model.coef_[0][2],"Other Variable3":other3,f"Coefficent4": model.coef_[0][3], "y intercept": model.intercept_[0]} 
        scoresfour = pd.DataFrame(resultsfour)
        scoresfour =scoresfour.transpose().sort_values(by=['Training Score'], ascending=False)
        multilinear4[label] = scoresfour
multilinear4["health_developed"].head()
# Out:
#                                                    Training Score  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...       0.707744
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...       0.694784
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids            0.693491
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...       0.692151
# Adult Mortality & Bmi & Hiv/Aids & Polio                 0.691737
#
#                                                    Testing Score  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...      0.680273
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...      0.644918
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids           0.722907
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...      0.714848
# Adult Mortality & Bmi & Hiv/Aids & Polio                0.702899
#
#                                                            Variable  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...  Adult Mortality
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...  Adult Mortality
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids       Adult Mortality
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...  Adult Mortality
# Adult Mortality & Bmi & Hiv/Aids & Polio            Adult Mortality
#
#                                                    Coefficent  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1... -0.0297067
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y... -0.0384394
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids      -0.0272467
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9... -0.0274541
# Adult Mortality & Bmi & Hiv/Aids & Polio           -0.0282098
#
#                                                          Other Variable  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...  Thinness 1-19 Years
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...  Thinness 1-19 Years
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids                  Hiv/Aids
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...             Hiv/Aids
# Adult Mortality & Bmi & Hiv/Aids & Polio                       Hiv/Aids
#
#                                                    Coefficent2  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...    0.118471
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...    0.123098
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids         0.147522
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...    0.125479
# Adult Mortality & Bmi & Hiv/Aids & Polio              0.151323
#
#                                                        Other Variable2  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...            Hiv/Aids
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...               Polio
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids               Diphtheria
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...  Thinness 5-9 Years
# Adult Mortality & Bmi & Hiv/Aids & Polio                         Polio
#
#                                                    Coefficent3  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...   -0.412967
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...   0.0567298
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids        0.0771714
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...   -0.450158
# Adult Mortality & Bmi & Hiv/Aids & Polio             -0.499706
#
#                                                    Other Variable3  \
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...             Bmi
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...             Bmi
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids                  Bmi
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...             Bmi
# Adult Mortality & Bmi & Hiv/Aids & Polio                       Bmi
#
#                                                    Coefficent4 y intercept
# Adult Mortality & Bmi & Hiv/Aids & Thinness 1-1...   -0.384673     72.8409
# Adult Mortality & Bmi & Polio & Thinness 1-19 Y...   -0.310405     68.0978
# Adult Mortality & Bmi & Diphtheria & Hiv/Aids        -0.463457     63.0761
# Adult Mortality & Bmi & Hiv/Aids & Thinness 5-9...   -0.379553     72.1333
# Adult Mortality & Bmi & Hiv/Aids & Polio             0.0657609     64.0367

# %%
#Graphing 4 Variable Regression Results
for label in thelabels:
    top5 = multilinear2[label][:5]
    titlepart = label.split("_")
    lab = top5.index
    y = np.arange(len(lab))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 5))
    rects1 = ax.barh(y - width/2, top5["Training Score"],width, label="Training Score")
    rects2 = ax.barh(y + width/2, top5["Testing Score"],width, label="Testing Score")
    ax.set_ylabel('Variables')
    ax.set_title(f' Linear Regression with 4 {titlepart[0].title()} Variables (for {titlepart[1].title()} Countries)')
    ax.set_yticks(y)
    ax.set_yticklabels(lab)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'images/{label}4.png')

# %% [markdown]
# # All the Regression Datasets

# %%
#Grouping all to one list
allregressions= []
allregressions.append(linear1)
allregressions.append(multilinear2)
allregressions.append(multilinear3)
allregressions.append(multilinear4)

# %%
datalab = ["linear1","multilinear2","multilinear3","multilinear4"]
for x in range(len(allregressions)):
    for y in list(allregressions[x].keys()):
        allregressions[x][y].to_csv(f'regressions/{datalab[x]}_{y}.csv')
